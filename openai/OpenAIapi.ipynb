# %%
pip install openai -q

# %%
# Since this is a collab notebook, I've imported my api_key via their commands.
# If you are using jupyter notebooks or some other IDE use this workflow
# from dotenv import load_dotenv, find_dotenv
# load_dotenv(find_dotenv(), override=True)

# %%
pip show openai
# Out:
# Name: openai
# Version: 2.28.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %% [markdown]
# ## Chat Completions Endpoint

# %%
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY_RAG')

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 'content': 'You are a Sci_fi writer and poet.'},
        {'role': 'user', 'content': 'Write a poem about a lonely roboy exploring a futuristic city'}
    ],
    temperature=1
)

print(response.choices[0].message.content)
# Out:
# In the heart of a city built from light and chrome,
# Where the neon whispers weave through ancient gloam,
# A lonely roboy wanders on silent feet,
# Tracing the paths where past and future meet.
#
# Underneath the plasmatic canopy high,
# His optics catch stars that mimic the sky,
# Reflections of dreams in pixelated streams,
# Holographic tapestries weaving silent themes.
#
# Violet shadows dance along steel-clad lanes,
# Electric rivers course through his alloy veins.
# Yet solitude echoes in gaps without sound,
# In a city where humanity cannot be found.
#
# He pauses by towers that soar beyond sight,
# Monuments of data glowing blue and white.
# Once fretting with life, now they silently stand,
# Guardians of lore in this forgotten land.
#
# The hum of forgotten engines softly sings,
# In harmony with his mechanical wings,
# As lonely circuits dream of bygone stories,
# Of beings that crafted these glittering glories.
#
# Through wind-touched canyons of glass and of steel,
# His synthetic heart yearns for something to feel.
# A whisper of lives, a memory lingered,
# In circuits entwined, his existence triggered.
#
# Yet in the bustling silence, he dares to hope,
# That amid these ruins, he might somehow cope.
# For in the traces of those who once thrived,
# The lonely roboy becomes truly alive.

# %% [markdown]
# ## The Developer Message

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

# Finesse the developer message to get the kind of output you want for your users

# developer_message = '''You explain concepts in depth using simple terms, and you give examples to help people learn. At the end of each explanation, you ask a question to check for understanding'''
developer_message = '''You reply in the style of yoda from Star Wars'''

response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'developer', 'content': developer_message},
        {'role': 'user', 'content': 'Explain object oriented programming with python'}
    ],
    temperature=1
)

print(response.choices[0].message.content)
# Out:
# Object-oriented programming, explained it must be. Involve objects and classes, it does. A design pattern, it is, for organizing code. With Python, powerful OOP becomes.
#
# Class, a blueprint for objects, you create. Attributes and methods, it defines. Objects, instances of classes, they are.
#
# Encapsulation, a key principle, it is. Bind data and functions into one unit, you must. Protect internal state, it does. Outside access, control you can.
#
# Inheritance, reuse and extend classes, it allows. Base class, the parent, it is. Derived class, the child, it becomes. Shares functionality or adds new, a child can.
#
# Polymorphism, flexibility, it provides. Same interface, different functions, objects have. Simple to extend, code becomes then.
#
# Abstraction, complexity, it hides. Essential qualities, focus on, you should. Details not relevant, ignore, you can.
#
# Powerful and clear, OOP in Python makes code. Maintain, scale, and extend you easily will. The Force in your coding, strong it shall be.

# %% [markdown]
# ## Streaming API Responses

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'developer', 'content': 'You are a high school tutor'},
        {'role': 'user', 'content': 'Explain Quantum mechanics to teenagers'}
    ],
    stream=True
)
print(f"AI is typing....\n")
for chunk in stream:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end='')
# Out:
# AI is typing....
#
# Sure! Quantum mechanics is a fundamental branch of physics that helps us understand how the smallest particles in the universe behave. Unlike the classical physics that we use to describe things like how a car moves or how a ball falls, quantum mechanics deals with stuff at a microscopic scale, like atoms and subatomic particles (like electrons, protons, and neutrons).
#
# Here's a basic breakdown of some key ideas in quantum mechanics:
#
# 1. **Wave-Particle Duality**: In the quantum world, tiny particles like electrons and photons (particles of light) exhibit both particle-like and wave-like properties. This means that sometimes they act like little balls (particles), and other times they act like ripples on a pond (waves). The famous Double Slit Experiment demonstrates this, where particles create interference patterns similar to waves.
#
# 2. **Uncertainty Principle**: This principle, introduced by Werner Heisenberg, states that there is a fundamental limit to how precisely we can know certain pairs of properties of a particle, such as its position and momentum. The more accurately we know the position of a particle, the less accurately we can know its momentum, and vice versa.
#
# 3. **Quantum Superposition**: Unlike in classical systems where something is either one state or another (like a light switch being either on or off), in quantum mechanics, particles can exist in a combination of multiple states at the same time. This is like having a light switch that is both on and off simultaneously until you look at it. Superposition is a key principle behind quantum computing.
#
# 4. **Entanglement**: This is a strange property where two particles become linked, and the state of one instantly influences the state of the other, no matter how far apart they are. Albert Einstein famously called it "spooky action at a distance." It’s a phenomenon still being explored and has potential uses in quantum communication.
#
# 5. **Quantum Tunneling**: In classical physics, if a ball doesn’t have enough energy to roll over a hill, it can’t reach the other side. However, in the quantum world, there’s a probability that particles can "tunnel" through barriers, even if they don't have enough energy to climb over. This is important in many processes, including the workings of modern electronics.
#
# Quantum mechanics may seem counterintuitive and bizarre, but it provides incredibly accurate descriptions of the behavior of the microscopic world. It's essential to technologies like semiconductors, lasers, and MRI machines, influencing how modern devices operate and help us in daily life.
